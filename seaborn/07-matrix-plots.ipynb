# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'D:\codebase\data-analysis-python\datasets\country_table.csv')

df.head()
# Out:
#            Countries  Birth rate  Mortality rate  Life expectancy  \
# 0             AFRICA      32.577           7.837           63.472
# 1               ASIA      15.796           7.030           73.787
# 2             EUROPE      10.118          11.163           78.740
# 3  LATAM & CARIBBEAN      15.886           6.444           75.649
# 4      NORTH AMERICA      11.780           8.833           79.269
#
#    Infant mortality rate  Growth rate
# 0                 44.215        24.40
# 1                 23.185         8.44
# 2                  3.750         0.38
# 3                 14.570         8.89
# 4                  5.563         6.11

# %%
df = df.set_index('Countries')

df.head()
# Out:
#                    Birth rate  Mortality rate  Life expectancy  \
# Countries
# AFRICA                 32.577           7.837           63.472
# ASIA                   15.796           7.030           73.787
# EUROPE                 10.118          11.163           78.740
# LATAM & CARIBBEAN      15.886           6.444           75.649
# NORTH AMERICA          11.780           8.833           79.269
#
#                    Infant mortality rate  Growth rate
# Countries
# AFRICA                            44.215        24.40
# ASIA                              23.185         8.44
# EUROPE                             3.750         0.38
# LATAM & CARIBBEAN                 14.570         8.89
# NORTH AMERICA                      5.563         6.11

# %%
plt.figure(dpi=500)
sns.heatmap(df.drop('Life expectancy', axis=1).transpose(), linewidths=0.5
            ,annot=True)

plt.savefig(r'.\visualizations\heatmap.png')
