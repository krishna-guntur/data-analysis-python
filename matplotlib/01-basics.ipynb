# %% [markdown]
# Basics of Matplotlib

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
x = np.arange(-10,10)

# %%
y = 3*x

# %%
plt.plot(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axix')
plt.title('y = mx')
plt.xlim(0, 8)
plt.ylim(0,16)

plt.savefig(r'.\visualizations\y=mx.png')
